# %% [markdown]
# # Data Analysis with ChatGPT
#
# In this file, we will perform a simple data analysis using ChatGPT as the main guide. To do this, we will send prompts externally to ChatGPT and follow the guidance it provides.
# This file was created as an independent study for Alura's "Análise de dados com Python: utilizando o ChatGPT como assistente" course.

# %% [markdown]
# ### Prompt 1 :
#
# We are going to work as data scientists for a clothing company.
#
# We have received data in CSV file format. The file is available in a local folder.
#
# We need to analyze this data to help with the company's decisions. We program in Python and are familiar with the Numpy and Pandas data analysis libraries. Therefore, prioritize the use of these libraries.
#
# Please let us know how we can read this data in CSV format and how we can visualize it in table format in Python.

# %%
# Importing libraries

import pandas as pd
import numpy as np

# %%
# Reading the CSV file

df = pd.read_csv("clothes_price_data.csv", sep= ',')

# %%
# Data visualization

df.head()
# Out:
#    ItemID ItemName   Brand    Category Size   Price
# 0       1   Jacket  BrandB   Outerwear    M   75.07
# 1       2  T-Shirt  BrandE    Footwear    S   45.61
# 2       3    Jeans  BrandE    Footwear    S  114.02
# 3       4    Shoes  BrandD    Footwear    S   52.76
# 4       5    Jeans  BrandC  Bottomwear    S  159.53

# %%
## Basic data inspection

# View DataFrame columns

df.columns
# Out:
# Index(['ItemID', 'ItemName', 'Brand', 'Category', 'Size', 'Price'], dtype='object')

# %%
# View the size of the DataFrame (number of rows and columns)

df.shape
# Out:
# (500, 6)

# %%
# Information about the DataFrame, such as data types and missing values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ItemID    500 non-null    int64
#  1   ItemName  500 non-null    object
#  2   Brand     500 non-null    object
#  3   Category  500 non-null    object
#  4   Size      500 non-null    object
#  5   Price     500 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 23.6+ KB

# %%
# Descriptive statistics for numerical data

df.describe()
# Out:
#            ItemID      Price
# count  500.000000  500.00000
# mean   250.500000  109.85000
# std    144.481833   54.94146
# min      1.000000   10.39000
# 25%    125.750000   62.76500
# 50%    250.500000  112.00000
# 75%    375.250000  159.05750
# max    500.000000  199.47000

# %% [markdown]
# ### Prompt 2:
#
# The DataFrame "df" contains data relating to different items of clothing, including their prices, brands, categories and sizes. The data is synthesized to reflect the diversity and variety of items found in an e-commerce environment.
#
# ItemID, each item's identifier; Item name; Item brand; Item category; Item size and Item price (in USD) are provided.
#
# We are starting the data exploration stage, in which we want to know the values entered and identify whether there are missing values, duplicates and other inconsistencies.
#
# Please build a code to perform the data exploration step using Python.
#
# It is not necessary to use "print()" to display the result of the queries.

# %%
## Show the First Rows
# to display the first rows of the DataFrame

df.head()
# Out:
#    ItemID ItemName   Brand    Category Size   Price
# 0       1   Jacket  BrandB   Outerwear    M   75.07
# 1       2  T-Shirt  BrandE    Footwear    S   45.61
# 2       3    Jeans  BrandE    Footwear    S  114.02
# 3       4    Shoes  BrandD    Footwear    S   52.76
# 4       5    Jeans  BrandC  Bottomwear    S  159.53

# %%
## Check Missing Values
# gives us the count of missing values per column.

df.isnull().sum()
# Out:
# ItemID      0
# ItemName    0
# Brand       0
# Category    0
# Size        0
# Price       0
# dtype: int64

# %%
## Check Duplicate Values
# returns the number of duplicate rows in the DataFrame.

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
## General DataFrame Information
# provides information about the DataFrame, such as the number of entries, columns and data types.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ItemID    500 non-null    int64
#  1   ItemName  500 non-null    object
#  2   Brand     500 non-null    object
#  3   Category  500 non-null    object
#  4   Size      500 non-null    object
#  5   Price     500 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 23.6+ KB

# %%
## Descriptive Statistics
# generates descriptive statistics for numerical columns.

df.describe()
# Out:
#            ItemID      Price
# count  500.000000  500.00000
# mean   250.500000  109.85000
# std    144.481833   54.94146
# min      1.000000   10.39000
# 25%    125.750000   62.76500
# 50%    250.500000  112.00000
# 75%    375.250000  159.05750
# max    500.000000  199.47000

# %%
## Column Data Types
# shows the data types of each column.

df.dtypes
# Out:
# ItemID        int64
# ItemName     object
# Brand        object
# Category     object
# Size         object
# Price       float64
# dtype: object

# %%
## Distribution of Unique Values in Categorical Columns
# counts the unique values in the categorical columns.

df.select_dtypes(include=['object']).nunique()
# Out:
# ItemName    5
# Brand       5
# Category    5
# Size        5
# dtype: int64

# %%
## Distribution of Values in the 'Category' Column
# counts the frequency of each category

df['Category'].value_counts()
# Out:
# Category
# Outerwear     109
# Topwear       103
# Bottomwear    100
# Dresses        97
# Footwear       91
# Name: count, dtype: int64

# %% [markdown]
# ### Prompt 3:
#
# The DataFrame "df" contains data related to the sales during a quarter of a store. I want to use it to check the performance of these sales.
#
# During the exploration of "df", we identified some inconsistencies, such as:
#
# - Duplicate rows,
# - Null values and
# - Categorical data that has been written in a non-standardized way, giving the idea that there are more categories than there actually are.
#
# What should I do to ensure that these inconsistencies I've found don't affect my analysis?

# %% [markdown]
# ### Prompt 4:
#
# The data in the "df" DataFrame has been cleaned and processed. Now I want to start building new variables/columns that will provide good support for analyzing the company's sales performance.
#
# The columns available in "df" are as follows:
# - ItemID: A unique identifier for each item of clothing.
# - ItemName: The name of the clothing item (e.g. T-shirt, jeans, jacket).
# - Brand: The brand associated with the item of clothing (e.g. BrandA, BrandB).
# - Category: The category under which the item of clothing falls (e.g. Topwear, Bottomwear, Outerwear).
# - Size: The size of the item of clothing (e.g. XS, S, M, L, XL).
# - Price: The price of the item of clothing in USD.
#
# The aim is to create variables or columns that provide relevant information for the company's managers.
#
# Based on the information provided, what types of variables/new columns would be useful to achieve the objective of analyzing sales performance?

# %%
## PriceRange
# Classifies items into price ranges, which can be useful for market analysis and segmentation

df['PriceRange'] = pd.cut(df['Price'], bins=[0, 20, 50, 100, 200, 500], labels=['0-20', '21-50', '51-100', '101-200', '201-500'])

# %%
## BrandCategory
# Combines brand and category to identify specific combinations

df['BrandCategory'] = df['Brand'] + ' - ' + df['Category']

# %%
## SizeAvailability
# Creates a column indicating the availability of popular sizes (optional, depending on other available data)

popular_sizes = ['M', 'L', 'XL']
df['SizeAvailability'] = df['Size'].apply(lambda x: 'Popular' if x in popular_sizes else 'Non-Popular')

# %%
## PricePerUnitSize
# Calculates the price per unit size, useful for comparing prices of items of different sizes

size_map = {'XS': 1, 'S': 2, 'M': 3, 'L': 4, 'XL': 5}  # Exemplo de mapeamento de tamanhos
df['PricePerUnitSize'] = df['Price'] / df['Size'].map(size_map)

# %%
## CategorySalesWeight
# Assigns a weight to categories based on a specific criterion, such as the number of sales (if this data is available)

category_weights = {
    'Outerwear': 1.5,
    'Topwear': 1.2,
    'Bottomwear': 1.0,
    'Dresses': 1.3,
    'Footwear': 1.4
}
df['CategorySalesWeight'] = df['Category'].map(category_weights)

# %%
## AveragePriceByBrand
# Calculates the average price of items by brand, useful for comparing the average price between different brands

avg_price_by_brand = df.groupby('Brand')['Price'].transform('mean')
df['AveragePriceByBrand'] = avg_price_by_brand

# %%
## IsPremiumBrand
# Identifies whether the brand is considered premium (based on a specific criterion such as average price above a certain value)

premium_threshold = 100  # Example of a reference value for premium brands
df['IsPremiumBrand'] = df['AveragePriceByBrand'] > premium_threshold

# %%
## PriceVarianceByCategory
# Calculates the variance of prices within each category, useful for understanding price dispersion

price_variance_by_category = df.groupby('Category')['Price'].transform('var')
df['PriceVarianceByCategory'] = price_variance_by_category

# %%
df.head()
# Out:
#    ItemID ItemName   Brand    Category Size   Price PriceRange  \
# 0       1   Jacket  BrandB   Outerwear    M   75.07     51-100
# 1       2  T-Shirt  BrandE    Footwear    S   45.61      21-50
# 2       3    Jeans  BrandE    Footwear    S  114.02    101-200
# 3       4    Shoes  BrandD    Footwear    S   52.76     51-100
# 4       5    Jeans  BrandC  Bottomwear    S  159.53    101-200
#
#          BrandCategory SizeAvailability  PricePerUnitSize  \
# 0   BrandB - Outerwear          Popular         25.023333
# 1    BrandE - Footwear      Non-Popular         22.805000
# 2    BrandE - Footwear      Non-Popular         57.010000
# 3    BrandD - Footwear      Non-Popular         26.380000
# 4  BrandC - Bottomwear      Non-Popular         79.765000
#
#    CategorySalesWeight  AveragePriceByBrand  IsPremiumBrand  \
# 0                  1.5           114.631545            True
# 1                  1.4           109.795981            True
# ...

# %% [markdown]
# ### Prompt 5:
#
# The data in the "df" DataFrame has been cleaned and processed. Now I want to start building graphs to create visualizations that provide good support for analyzing the company's sales performance.
#
# The columns available in "df" are as follows:
# - ItemID: A unique identifier for each item of clothing.
# - ItemName: The name of the clothing item (e.g. T-shirt, jeans, jacket).
# - Brand: The brand associated with the item of clothing (e.g. BrandA, BrandB).
# - Category: The category under which the item of clothing falls (e.g. Topwear, Bottomwear, Outerwear).
# - Size: The size of the item of clothing (e.g. XS, S, M, L, XL).
# - Price: The price of the item of clothing in USD.
# - PriceRange: The price range the article of clothing falls into (e.g. 0-20, 21-50, 51-100, 101-200, 201-500 USD).
# - BrandCategory: Combination of the brand and category of the clothing item (e.g. BrandA - Topwear).
# - SizeAvailability: Indicates whether the size of the clothing item is popular (Popular for sizes M, L, XL; Non-Popular for all other sizes).
# - PricePerUnitSize: The price of the article of clothing per unit size (calculated on the basis of a mapping of sizes to numbers).
# - CategorySalesWeight: A weight assigned to the category of the clothing item based on a specific criterion (e.g. Outerwear: 1.5, Topwear: 1.2, Bottomwear: 1.0, Dresses: 1.3, Footwear: 1.4).
# - AveragePriceByBrand: The average price of clothing items by brand.
# - IsPremiumBrand: Indicates whether the brand is considered premium, based on the average price of the brand's items (premium if average price > 100 USD).
# - PriceVarianceByCategory: The variance of clothing prices within each category.
#
# Based on the information provided, what types of visualizations would be useful to achieve the objective of analyzing sales performance?
#
# The plot figures should follow the store's visual identity, with the background of the figure and plot in the color "#ebebeb" and the bars in the color "#e23155".

# %%
# Price Distribution by Category

import matplotlib.pyplot as plt
import seaborn as sns

# Style setting
sns.set(style="whitegrid")
plt.rcParams['figure.facecolor'] = '#ebebeb'
plt.rcParams['axes.facecolor'] = '#ebebeb'

# Bar chart for average prices by category
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Price', data=df, palette=["#e23155"])
plt.title('Média de Preços por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Preço Médio (USD)', fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\79109174.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Price', data=df, palette=["#e23155"])
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\79109174.py:13: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Category', y='Price', data=df, palette=["#e23155"])

# %%
# Distribution of Popular vs. Unpopular Sizes

# Bar chart for the distribution of popular vs. non-popular sizes
plt.figure(figsize=(8, 6))
sns.countplot(x='SizeAvailability', data=df, palette=["#e23155"])
plt.title('Distribuição de Tamanhos Populares vs. Não Populares', fontsize=16)
plt.xlabel('Disponibilidade de Tamanho', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
plt.show()
# Out:
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\77268015.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='SizeAvailability', data=df, palette=["#e23155"])
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\77268015.py:5: UserWarning:
# The palette list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='SizeAvailability', data=df, palette=["#e23155"])

# %%
# Average Price by Brand

# Bar chart for the average price per brand
plt.figure(figsize=(12, 8))
sns.barplot(x='Brand', y='Price', data=df, palette=["#e23155"])
plt.title('Média de Preços por Marca', fontsize=16)
plt.xlabel('Marca', fontsize=14)
plt.ylabel('Preço Médio (USD)', fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\3766374799.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Brand', y='Price', data=df, palette=["#e23155"])
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\3766374799.py:5: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Brand', y='Price', data=df, palette=["#e23155"])

# %%
# Price Ranges

# Bar chart for the distribution of price ranges
plt.figure(figsize=(10, 6))
sns.countplot(x='PriceRange', data=df, palette=["#e23155"])
plt.title('Distribuição de Faixas de Preço', fontsize=16)
plt.xlabel('Faixa de Preço (USD)', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
plt.show()
# Out:
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\3444862758.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PriceRange', data=df, palette=["#e23155"])
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\3444862758.py:5: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='PriceRange', data=df, palette=["#e23155"])

# %%
# Price Variance by Category

# Bar chart for price variance by category
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='PriceVarianceByCategory', data=df, palette=["#e23155"])
plt.title('Variância de Preços por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Variância de Preços', fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\3835655320.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='PriceVarianceByCategory', data=df, palette=["#e23155"])
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\3835655320.py:5: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Category', y='PriceVarianceByCategory', data=df, palette=["#e23155"])

# %%
# Distribution of Items by Category

# Bar chart for the distribution of items by category
plt.figure(figsize=(10, 6))
sns.countplot(x='Category', data=df, palette=["#e23155"])
plt.title('Distribuição de Itens por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\1607133604.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Category', data=df, palette=["#e23155"])
# C:\Users\gabis\AppData\Local\Temp\ipykernel_17136\1607133604.py:5: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='Category', data=df, palette=["#e23155"])

# %%
# Average Price by Category and Brand

# Grouped bar chart for average price by category and brand
plt.figure(figsize=(14, 8))
sns.barplot(x='Category', y='Price', hue='Brand', data=df)
plt.title('Média de Preços por Categoria e Marca', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Preço Médio (USD)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Marca')
plt.show()

# %% [markdown]
# ### Prompt 6:
#
# I want to create a visualization that allows me to identify the total obtained in sales by product categories in a horizontal bar chart.
#
# The data needs to be grouped by category.
#
# The figure in the plot must follow the store's visual identity, with the background of the figure and the plot in the color "#ebebeb".
#
# The bars must be colored "#e23155".
#
# The bar values need to be ordered to maintain a funnel look.
#
# In addition, you need to display the total sales in millions inside or next to each bar, with the text of this information in the color "#19325c" and in the structure "R$ value M".
#
# Don't show the grid in the plot.
#
# Use Python's data visualization libraries to create this visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group data by category and calculate total sales by category
total_sales_by_category = df.groupby('Category')['Price'].sum().reset_index()

# Sort the categories by total sales in descending order
total_sales_by_category = total_sales_by_category.sort_values(by='Price', ascending=False)

# Style setting
sns.set(style="whitegrid")
plt.rcParams['figure.facecolor'] = '#ebebeb'
plt.rcParams['axes.facecolor'] = '#ebebeb'

# Adjust the size of the picture
plt.figure(figsize=(14, 6))  # I increased the width and decreased the height for thinner bars

# Create the horizontal bar chart
bars = plt.barh(total_sales_by_category['Category'], total_sales_by_category['Price'], color='#e23155', height=0.5)

# Add the sales figures in millions next to each bar
for bar in bars:
    width = bar.get_width()
    label = f"R$ {width / 1e6:.2f} M"
    plt.text(width, bar.get_y() + bar.get_height() / 2, label, va='center', ha='left', color='#19325c', fontsize=12)

# Adjust title and labels
plt.title('Total de Vendas por Categoria de Produtos', fontsize=16)
plt.xlabel('Total de Vendas (USD)', fontsize=14)
plt.ylabel('Categoria', fontsize=14)
plt.gca().invert_yaxis()  # Invert the y-axis to sort from top to bottom

# Remove the grid
plt.grid(False)

# Adjust spacing
plt.tight_layout()

# Display the graphic
plt.show()

# %% [markdown]
# #### Prompt 7:
#
# We are going to work as data scientists for a clothing company.
# We need to analyze this data to help with company decisions.
# The DataFrame "df" contains data relating to different items of clothing, including their prices, brands, categories and sizes. The data is synthesized to reflect the diversity and variety of items found in an e-commerce environment.
#
# ItemID, each item's identifier; Item name; Item brand; Item category; Item size and Item price (in USD) are provided.
#
# The columns available in "df" are as follows:
# - ItemID: A unique identifier for each item of clothing.
# - ItemName: The name of the clothing item (e.g. T-shirt, jeans, jacket).
# - Brand: The brand associated with the item of clothing (e.g. BrandA, BrandB).
# - Category: The category under which the item of clothing falls (e.g. Topwear, Bottomwear, Outerwear).
# - Size: The size of the item of clothing (e.g. XS, S, M, L, XL).
# - Price: The price of the item of clothing in USD.
# - PriceRange: The price range the article of clothing falls into (e.g. 0-20, 21-50, 51-100, 101-200, 201-500 USD).
# - BrandCategory: Combination of the brand and category of the clothing item (e.g. BrandA - Topwear).
# - SizeAvailability: Indicates whether the size of the clothing item is popular (Popular for sizes M, L, XL; Non-Popular for all other sizes).
# - PricePerUnitSize: The price of the clothing item per unit size (calculated on the basis of a mapping of sizes to numbers).
# - CategorySalesWeight: A weight assigned to the category of the clothing item based on a specific criterion (e.g. Outerwear: 1.5, Topwear: 1.2, Bottomwear: 1.0, Dresses: 1.3, Footwear: 1.4).
# - AveragePriceByBrand: The average price of clothing items by brand.
# - IsPremiumBrand: Indicates whether the brand is considered premium, based on the average price of the brand's items (premium if average price > 100 USD).
# - PriceVarianceByCategory: The variance of clothing prices within each category.
#
# Based on this information, analyze the image
#
# {graphic_1}

# %% [markdown]
# ### Analysis of the data in the graph
#
# - Outerwear:** Shows an average price of around 110 USD.
# - **Footwear:** Average price close to 115 USD.
# - **Bottomwear:** Average price just above 110 USD.
# - **Dresses:** Average price slightly below 110 USD.
# - Topwear:** Average price also close to 110 USD.
#
# ### Considerations for Analysis
#
# 1. **Price Comparison:** All categories have relatively close average prices, ranging from approximately 105 USD to 115 USD. This suggests a uniform pricing strategy between the different clothing categories.
# 2. **Price Variation:** The error bars indicate the price variability within each category. A larger error bar may indicate a greater diversity of prices within that category, while a smaller error bar suggests more uniform prices.
# 3. **Pricing decisions:** If the company intends to adjust its prices, it can consider the categories with the greatest variability (larger error bars) in order to further analyze the factors that influence this variation, such as product quality, brand and demand.
# 4. **Category Focus:** Categories with lower average prices can be examined to identify opportunities for price increases, especially if there is a perception of high value or demand for these items.

# %% [markdown]
# ### Analysis of the data in the graph
#
# - Popular:** Represents the count of clothing items that have popular sizes (sizes M, L, XL).
# - **Non-Popular:** Represents the count of clothing items that have non-popular sizes (other sizes).
#
# ### Considerations for Analysis
#
# 1. **Distribution of Sizes
#    - There are more clothing items in popular sizes (approximately 280) than in non-popular sizes (approximately 220).
#    - This may indicate a greater demand for popular sizes, or a greater supply of products in these sizes.
#
# 2. **Inventory Planning:**
#    - The company should consider keeping a larger stock of items in popular sizes to meet demand.
#    - Analyzing the stock turnover of these sizes can be useful to avoid stockouts and overstocks.
#
# 3. **Demand Analysis**
#    - If demand for popular sizes is consistently high, it can be interesting to investigate whether this trend continues across all product categories (e.g. Topwear, Bottomwear, etc.).
#    - The company can adjust its purchasing and production strategies based on this information.
#
# 4. **Marketing strategy**
#    - Targeted marketing campaigns can be developed to promote unpopular sizes in order to balance demand.
#    - Promotions or discounts on unpopular sizes can help reduce excess stock of these items.
#
# 5. **Impact on Prices**
#    - It can be analyzed whether there is a significant difference in average prices between popular and non-popular item sizes, and whether this difference justifies price adjustments.
#
# ### Next Steps
#
# For a more detailed analysis, you could consider:
# - Investigating the distribution of sizes within each product category.
# - Analyzing the relationship between size popularity and sales performance.
# - Evaluating price variation by size and how this impacts profitability.
